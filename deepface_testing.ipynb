# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=840d9a812c064aa93b5d81cfe7c6ad77ea975f4698be59ec6894b558c00174d2
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 25-05-21 06:46:57 - Directory /root/.deepface has been created
# 25-05-21 06:46:57 - Directory /root/.deepface/weights has been created

# %%
result = DeepFace.verify(img1_path = "/content/img1.jpg", img2_path = "/content/img10.jpg")
# Out:
# 25-05-21 04:03:37 - vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:02<00:00, 254MB/s]

# %%
print(result)
# Out:
# {'verified': True, 'distance': 0.6160603205984431, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 339, 'y': 218, 'w': 768, 'h': 768, 'left_eye': (850, 524), 'right_eye': (571, 517)}, 'img2': {'x': 46, 'y': 103, 'w': 296, 'h': 296, 'left_eye': (244, 220), 'right_eye': (138, 218)}}, 'time': 13.99}

# %%
objs = DeepFace.analyze(
  img_path = "/content/img11.jpg", actions = ['age', 'gender', 'race', 'emotion']
)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-05-21 06:47:03 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   3%|▎         | 16.3M/539M [00:00<00:03, 162MB/s]
#   8%|▊         | 40.9M/539M [00:00<00:02, 210MB/s]
#  13%|█▎        | 71.3M/539M [00:00<00:01, 250MB/s]
#  19%|█▉        | 102M/539M [00:00<00:01, 273MB/s]
#  24%|██▍       | 129M/539M [00:00<00:01, 244MB/s]
#  29%|██▊       | 155M/539M [00:00<00:01, 217MB/s]
#  33%|███▎      | 177M/539M [00:00<00:01, 190MB/s]
#  37%|███▋      | 197M/539M [00:01<00:02, 145MB/s]
#  40%|███▉      | 214M/539M [00:01<00:03, 86.4MB/s]
#  42%|████▏     | 226M/539M [00:01<00:05, 61.6MB/s]
#  44%|████▍     | 236M/539M [00:02<00:06, 48.3MB/s]
#  45%|████▌     | 244M/539M [00:02<00:06, 42.2MB/s]
# ...

# %%
print(objs)
# Out:
# [{'age': 33, 'region': {'x': 128, 'y': 87, 'w': 358, 'h': 358, 'left_eye': (372, 247), 'right_eye': (248, 211)}, 'face_confidence': np.float64(0.93), 'gender': {'Woman': np.float32(99.99974), 'Man': np.float32(0.0002676721)}, 'dominant_gender': 'Woman', 'race': {'asian': np.float32(0.21381325), 'indian': np.float32(0.89998573), 'black': np.float32(0.012534438), 'white': np.float32(83.35741), 'middle eastern': np.float32(8.240636), 'latino hispanic': np.float32(7.275626)}, 'dominant_race': 'white', 'emotion': {'angry': np.float32(3.743191), 'disgust': np.float32(5.1034134e-05), 'fear': np.float32(34.975353), 'happy': np.float32(0.05261566), 'sad': np.float32(4.490708), 'surprise': np.float32(53.714573), 'neutral': np.float32(3.023503)}, 'dominant_emotion': 'surprise'}]
