# %%
# alternative: https://github.com/mnicnc404/CartoonGan-tensorflow
# !git clone https://github.com/Yijunmaverick/CartoonGAN-Test-Pytorch-Torch
# try Hugguingface CartoonGan
# Out:
# Cloning into 'CartoonGAN-Test-Pytorch-Torch'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 154 (delta 0), reused 2 (delta 0), pack-reused 151 (from 1)
# Receiving objects: 100% (154/154), 11.99 MiB | 31.89 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
# !cd CartoonGAN-Test-Pytorch-Torch
# Out:
# sh: 0: cannot open pretrained_model/download_pth.sh: No such file

# %%
# !ls
# Out:
# CartoonGAN-Test-Pytorch-Torch  sample_data

# %%
# !ls -d $PWD
# Out:
# /content

# %%
# !python /content/CartoonGAN-Test-Pytorch-Torch/test.py --input_dir /content/CartoonGAN-Test-Pytorch-Torch/test_img/15-324.jpg --style Hosoda --gpu 0
# Out:
# Traceback (most recent call last):
#   File "/content/CartoonGAN-Test-Pytorch-Torch/test.py", line 27, in <module>
#     model.load_state_dict(torch.load(os.path.join(opt.model_path, opt.style + '_net_G_float.pth')))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1425, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 751, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 732, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './pretrained_model/Hosoda_net_G_float.pth'
